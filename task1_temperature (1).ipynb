# %%
def convert_temperature():
    print("--- Temperature Converter ---")
    
    try:
        # 1. Get user input
        temp = float(input("Enter the temperature value: "))
        unit = input("Enter the original unit (C, F, or K): ").strip().upper()

        # 2. Perform conversions based on the unit
        if unit == 'C':
            fahrenheit = (temp * 9/5) + 32
            kelvin = temp + 273.15
            print(f"{temp}°C is equal to {fahrenheit:.2f}°F and {kelvin:.2f}K")

        elif unit == 'F':
            celsius = (temp - 32) * 5/9
            kelvin = celsius + 273.15
            print(f"{temp}°F is equal to {celsius:.2f}°C and {kelvin:.2f}K")

        elif unit == 'K':
            celsius = temp - 273.15
            fahrenheit = (celsius * 9/5) + 32
            print(f"{temp}K is equal to {celsius:.2f}°C and {fahrenheit:.2f}°F")

        else:
            print("Invalid unit. Please enter C, F, or K.")

    except ValueError:
        print("Invalid input. Please enter a numeric value for the temperature.")

# Run the program
if __name__ == "__main__":
    convert_temperature()
# Out:
# --- Temperature Converter ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 33
#      31 # Run the program
#      32 if __name__ == "__main__":
# ---> 33     convert_temperature()
#
# Cell In[1], line 6, in convert_temperature()
#       2 print("--- Temperature Converter ---")
#       4 try:
#       5     # 1. Get user input
# ----> 6     temp = float(input("Enter the temperature value: "))
#       7     unit = input("Enter the original unit (C, F, or K): ").strip().upper()
#       9     # 2. Perform conversions based on the unit
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
# ...
